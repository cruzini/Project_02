# %%
import pandas as pd

# %%
df = pd.read_excel('Personal_Fashion.xlsx')

# %%
df.head(n=3)
# Out:
#    Sample_ID  Age  Gender  Height(cm)  Weight(kg)           District  \
# 0          1   26  Female         160        60.0  Tel Aviv District
# 1          2   40  Female         166        65.0     Haifa District
# 2          3   23    Male         187        69.0  Tel Aviv District
#
#     Home_Town  Amount_Of_Clothes_Owned  Monthly_Income          Education  \
# 0     תל אביב                    100.0             0.0  Bachelor's Degree
# 1  קרית טבעון                     80.0          6000.0    Master's Degree
# 2       חולון                     35.0           200.0  Bachelor's Degree
#
#    ... Garment_Material Garment_Department Garment_Size  \
# 0  ...            Shiny               נשים           XS
# 1  ...           Cotton               נשים            S
# 2  ...           Cotton              גברים            M
#
#    Wearing_Frequency_text Wearing_Frequency_Yearly  \
# 0            עוד לא לבשתי                      0.0
# 1                פעם בשנה                      1.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 26 columns):
# Sample_ID                      204 non-null int64
# Age                            204 non-null int64
# Gender                         204 non-null object
# Height(cm)                     204 non-null int64
# Weight(kg)                     204 non-null float64
# District                       166 non-null object
# Home_Town                      204 non-null object
# Amount_Of_Clothes_Owned        121 non-null float64
# Monthly_Income                 146 non-null float64
# Education                      204 non-null object
# Garment_Type                   204 non-null object
# Garment_Description            204 non-null object
# Brand                          191 non-null object
# Year_Of_Acquiring              204 non-null int64
# Closest_Color                  204 non-null object
# Prints_And_Special_Features    204 non-null object
# ...

# %%
df.describe()
# Out:
#         Sample_ID         Age  Height(cm)  Weight(kg)  \
# count  204.000000  204.000000  204.000000  204.000000
# mean    69.362745   38.602941  167.436275   65.151961
# std     40.100561   15.103720    9.349843   13.476451
# min      1.000000   14.000000  148.000000   41.000000
# 25%     37.750000   24.000000  160.000000   56.000000
# 50%     68.500000   37.000000  165.000000   65.000000
# 75%    103.250000   49.000000  174.000000   73.000000
# max    140.000000   75.000000  189.000000  155.000000
#
#        Amount_Of_Clothes_Owned  Monthly_Income  Year_Of_Acquiring  \
# count                121.00000      146.000000         204.000000
# mean                 122.14876    18697.041096        2017.323529
# std                  124.22900    82473.026994           3.964527
# min                   10.00000        0.000000        1988.000000
# 25%                   50.00000     5000.000000        2016.000000
# 50%                   80.00000    10000.000000        2019.000000
# ...

# %%
df['Age'].mean()
# Out:
# 38.60294117647059

# %%
df['Height(cm)'].mean()
# Out:
# 167.43627450980392

# %%
df['Height(cm)'] = df['Height(cm)'].map(lambda x: ((x/2.54)/12))

# %%
df['Height(cm)'].mean()
# Out:
# 5.493316092841336

# %%
df = df.rename(columns={'Height(cm)':'Height', 'Weight(kg)':'Weight'})

# %%
df.head(n=3)
# Out:
#    Sample_ID  Age  Gender    Height  Weight           District   Home_Town  \
# 0          1   26  Female  5.249344    60.0  Tel Aviv District     תל אביב
# 1          2   40  Female  5.446194    65.0     Haifa District  קרית טבעון
# 2          3   23    Male  6.135171    69.0  Tel Aviv District       חולון
#
#    Amount_Of_Clothes_Owned  Monthly_Income          Education  ...  \
# 0                    100.0             0.0  Bachelor's Degree  ...
# 1                     80.0          6000.0    Master's Degree  ...
# 2                     35.0           200.0  Bachelor's Degree  ...
#
#   Garment_Material Garment_Department Garment_Size  Wearing_Frequency_text  \
# 0            Shiny               נשים           XS            עוד לא לבשתי
# 1           Cotton               נשים            S                פעם בשנה
# 2           Cotton              גברים            M          2 פעמים בשבוע
#
#   Wearing_Frequency_Yearly                         Garment_Wearing_Occasion  \
# ...

# %%
df['Weight'] = df['Weight'].map(lambda x: x*2.205)

# %%
df.head(n=3)
# Out:
#    Sample_ID  Age  Gender    Height   Weight           District   Home_Town  \
# 0          1   26  Female  5.249344  132.300  Tel Aviv District     תל אביב
# 1          2   40  Female  5.446194  143.325     Haifa District  קרית טבעון
# 2          3   23    Male  6.135171  152.145  Tel Aviv District       חולון
#
#    Amount_Of_Clothes_Owned  Monthly_Income          Education  ...  \
# 0                    100.0             0.0  Bachelor's Degree  ...
# 1                     80.0          6000.0    Master's Degree  ...
# 2                     35.0           200.0  Bachelor's Degree  ...
#
#   Garment_Material Garment_Department Garment_Size  Wearing_Frequency_text  \
# 0            Shiny               נשים           XS            עוד לא לבשתי
# 1           Cotton               נשים            S                פעם בשנה
# 2           Cotton              גברים            M          2 פעמים בשבוע
#
#   Wearing_Frequency_Yearly                         Garment_Wearing_Occasion  \
# ...
